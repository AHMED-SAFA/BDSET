# %%
print('hello world')
# Out:
# hello world

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.8 MB 1.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.8 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.8 MB 1.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/7.8 MB 1.2 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/7.8 MB 1.2 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/7.8 MB 1.2 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/7.8 MB 1.2 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.8 MB 783.9 kB/s eta 0:00:08
#    -------- ------------------------------- 1.6/7.8 MB 783.9 kB/s eta 0:00:08
#    -------- ------------------------------- 1.6/7.8 MB 783.9 kB/s eta 0:00:08
# ...

# %%
import numpy as np

a = np.empty([2,3],dtype=int) # empty # zeros # arange # zeros_like # array
print(a)
# Out:
# [[25895968444448860 23925768161198147 32370111954616435]
#  [23362715129086044 18296268628688965 27303364806049904]]

# %%
a = np.arange(20,10,-2) # empty # zeros # arange # zeros_like # array
#print(a)

b=np.array(["5ab",2,3,4,6])
d=np.array([1,2,"3",5])
print(d.shape[0])
# c = np.zeros(b.shape[0],dtype=int)
# c[:4] = 
b[:4]+d


# print(c)
# Out:
# 4
# array(['5ab1', '22', '33', '45'], dtype='<U42')

# %%
import pandas as pd

a = pd.read_csv('test.csv')

a.filter(['name','roll'])

a = a.dropna(how='any',axis=0)

print(a)
# Out:
#    id    name   roll
# 0   1  sourav   33.0
# 1   2   hamim   90.0
# 2   1  sourav   60.0
# 3   2   hamim  100.0
# 4   1  sourav   33.0

# %%
import matplotlib.pyplot as plt


plt.hist(a['roll'])
# Out:
# (array([2., 0., 0., 0., 1., 0., 0., 0., 1., 1.]),
#  array([ 33. ,  39.7,  46.4,  53.1,  59.8,  66.5,  73.2,  79.9,  86.6,
#          93.3, 100. ]),
#  <BarContainer object of 10 artists>)
